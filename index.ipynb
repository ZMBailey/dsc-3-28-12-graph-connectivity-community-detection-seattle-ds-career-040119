# %% [markdown]
# # Community Detection - Lab
#
# ## Introduction
#
# In this lab, you'll once again work to cluster a network dataset. This time, you'll be investigating a meetup dataset for events occurring in Nashville.
#
# ## Objectives
#
# You will be able to:
# * Cluster a social network into subgroups

# %% [markdown]
# ## Load the Dataset
#
# To start, load the dataset `'nashville-meetup/group-edges.csv'` as a pandas Dataframe.

# %%
import pandas as pd
edges_df = pd.read_csv('nashville-meetup/group-edges.csv', index_col='Unnamed: 0')
edges_df.head()
# Out:
#      group1    group2  weight
# 0  19292162    535553       2
# 1  19292162  19194894       1
# 2  19292162  19728145       1
# 3  19292162  18850080       2
# 4  19292162   1728035       1

# %%
print(edges_df.group1.nunique())
print(meta_df.group_id.nunique())
# Out:
# 409
# 602

# %% [markdown]
# To add some descriptive data, import the file `'nashville-meetup/meta-groups.csv'`.

# %%
meta_df = pd.read_csv('nashville-meetup/meta-groups.csv')
meta_df.head()
# Out:
#    group_id                                 group_name  num_members  \
# 0    339011                    Nashville Hiking Meetup        15838
# 1  19728145           Stepping Out Social Dance Meetup         1778
# 2   6335372                           Nashville soccer         2869
# 3  10016242                                     NashJS         1975
# 4  21174496  20's & 30's Women looking for girlfriends         2782
#
#    category_id         category_name  organizer_id             group_urlname
# 0           23  Outdoors & Adventure       4353803          nashville-hiking
# 1            5               Dancing     118484462    steppingoutsocialdance
# 2           32   Sports & Recreation     108448302          Nashville-soccer
# 3           34                  Tech       8111102                    nashjs
# 4           31           Socializing     184580248  new-friends-in-Nashville

# %% [markdown]
# ## Transform to a Network Representation
#
# Take the Pandas DataFrame and transform it into a graph representation via NetworkX. Make nodes the names of the various groups within the Nashville area. The edges should be the weights between these groups.

# %%
import networkx as nx

G = nx.graph

for r in edges_df.iterrows():
#     start = meta_df[meta_df['group_id'] == r['group1']]['group_name']
#     end = meta_df.loc[meta_df['group_id'] == r['group2'],'group_name']
#     weight = edges_df[r]['weight']
#     G.add_edge(start,end,weight)
    print(r)
# meta_df[meta_df['group_id'] == edges_df['group1']]#['group_name']
# Out:
# (0, group1    19292162
# group2      535553
# weight           2
# Name: 0, dtype: int64)
# (1, group1    19292162
# group2    19194894
# weight           1
# Name: 1, dtype: int64)
# (2, group1    19292162
# group2    19728145
# weight           1
# Name: 2, dtype: int64)
# (3, group1    19292162
# group2    18850080
# weight           2
# Name: 3, dtype: int64)
# (4, group1    19292162
# group2     1728035
# weight           1
# Name: 4, dtype: int64)
# (5, group1    19292162
# group2    22817838
# weight           2
# Name: 5, dtype: int64)
# (6, group1    19292162
# group2    19997487
# weight           2
# Name: 6, dtype: int64)
# (7, group1    19292162
# group2    18855476
# weight           2
# Name: 7, dtype: int64)
# (8, group1    19292162
# group2    18955830
# weight           1
# Name: 8, dtype: int64)
# (9, group1    19292162
# group2    11294262
# weight           1
# Name: 9, dtype: int64)
# (10, group1    19292162
# group2     1360698
# weight           2
# Name: 10, dtype: int64)
# (11, group1    19292162
# group2     1179719
# weight           1
# Name: 11, dtype: int64)
# (12, group1    19292162
# group2     1457232
# weight           1
# Name: 12, dtype: int64)
# (13, group1    19292162
# group2    13560402
# weight           1
# Name: 13, dtype: int64)
# (14, group1    19292162
# group2     7151442
# weight           1
# Name: 14, dtype: int64)
# (15, group1    19292162
# group2    18506072
# weight           1
# Name: 15, dtype: int64)
# (16, group1    19292162
# group2    16477792
# weight           2
# Name: 16, dtype: int64)
# (17, group1    19292162
# group2    20947040
# weight           1
# Name: 17, dtype: int64)
# (18, group1    19292162
# group2     5618532
# weight           1
# Name: 18, dtype: int64)
# (19, group1    19292162
# group2    11625832
# weight           5
# Name: 19, dtype: int64)
# (20, group1    19292162
# group2    18837102
# weight           1
# Name: 20, dtype: int64)
# (21, group1    19292162
# group2     7130232
# weight           1
# Name: 21, dtype: int64)
# (22, group1    19292162
# group2     3173762
# weight           1
# Name: 22, dtype: int64)
# (23, group1    19292162
# group2    16487812
# weight           5
# Name: 23, dtype: int64)
# (24, group1    19292162
# group2     7836842
# weight           6
# Name: 24, dtype: int64)
# (25, group1    19292162
# group2    17467312
# weight           3
# Name: 25, dtype: int64)
# (26, group1    19292162
# group2    16447162
# weight           1
# Name: 26, dtype: int64)
# (27, group1    19292162
# group2     9376702
# weight           3
# Name: 27, dtype: int64)
# (28, group1    19292162
# group2     6707902
# weight           2
# Name: 28, dtype: int64)
# (29, group1    19292162
# group2    10178242
# weight          12
# Name: 29, dtype: int64)
# (30, group1    19292162
# group2    14546632
# weight           1
# Name: 30, dtype: int64)
# (31, group1    19292162
# group2    14649032
# weight           1
# Name: 31, dtype: int64)
# (32, group1    19292162
# group2     4705492
# weight           1
# Name: 32, dtype: int64)
# (33, group1    19292162
# group2    18616278
# weight           1
# Name: 33, dtype: int64)
# (34, group1    19292162
# group2      526316
# weight           2
# Name: 34, dtype: int64)
# (35, group1    19292162
# group2    10016242
# weight           5
# Name: 35, dtype: int64)
# (36, group1    19292162
# group2    19654655
# weight           1
# Name: 36, dtype: int64)
# (37, group1    21182471
# group2     1187715
# weight           1
# Name: 37, dtype: int64)
# (38, group1    21182471
# group2    25357512
# weight           1
# Name: 38, dtype: int64)
# (39, group1    21182471
# group2    19728145
# weight           2
# Name: 39, dtype: int64)
# (40, group1    21182471
# group2     7699922
# weight           1
# Name: 40, dtype: int64)
# (41, group1    21182471
# group2    20940321
# weight           1
# Name: 41, dtype: int64)
# (42, group1    21182471
# group2    18801828
# weight           1
# Name: 42, dtype: int64)
# (43, group1    21182471
# group2     1642477
# weight           1
# Name: 43, dtype: int64)
# (44, group1    21182471
# group2    18243826
# weight           1
# Name: 44, dtype: int64)
# (45, group1    21182471
# group2    18297014
# weight           2
# Name: 45, dtype: int64)
# (46, group1    21182471
# group2     1473660
# weight           1
# Name: 46, dtype: int64)
# (47, group1    18288648
# group2    21715712
# weight           1
# Name: 47, dtype: int64)
# (48, group1    18288648
# group2    18562307
# weight           1
# Name: 48, dtype: int64)
# (49, group1    18288648
# group2      541319
# weight           1
# Name: 49, dtype: int64)
# (50, group1    18288648
# group2    19728145
# weight           2
# Name: 50, dtype: int64)
# (51, group1    18288648
# group2     7836842
# weight           2
# Name: 51, dtype: int64)
# (52, group1    18288648
# group2    17467312
# weight           1
# Name: 52, dtype: int64)
# (53, group1    18288648
# group2     1697586
# weight           1
# Name: 53, dtype: int64)
# (54, group1    18288648
# group2    18955830
# weight           1
# Name: 54, dtype: int64)
# (55, group1    18288648
# group2     4063542
# weight           1
# Name: 55, dtype: int64)
# (56, group1    18288648
# group2    18767675
# weight           1
# Name: 56, dtype: int64)
# (57, group1    18288648
# group2      339011
# weight           1
# Name: 57, dtype: int64)
# (58, group1    18288648
# group2    18556100
# weight           1
# Name: 58, dtype: int64)
# (59, group1    18288648
# group2    16062152
# weight           2
# Name: 59, dtype: int64)
# (60, group1    18288648
# group2     1417288
# weight           1
# Name: 60, dtype: int64)
# (61, group1    18288648
# group2    22985677
# weight           1
# Name: 61, dtype: int64)
# (62, group1    18288648
# group2     1457232
# weight           1
# Name: 62, dtype: int64)
# (63, group1    18288648
# group2    19266390
# weight           1
# Name: 63, dtype: int64)
# (64, group1    18288648
# group2    18506072
# weight           1
# Name: 64, dtype: int64)
# (65, group1    18288648
# group2     1498076
# weight           1
# Name: 65, dtype: int64)
# (66, group1    18288648
# group2    21174496
# weight           1
# Name: 66, dtype: int64)
# (67, group1    18288648
# group2    20947040
# weight           1
# Name: 67, dtype: int64)
# (68, group1    18288648
# group2    18529135
# weight           1
# Name: 68, dtype: int64)
# (69, group1    18288648
# group2    19094001
# weight           1
# Name: 69, dtype: int64)
# (70, group1    18288648
# group2    18243826
# weight           1
# Name: 70, dtype: int64)
# (71, group1    18288648
# group2    15297782
# weight           1
# Name: 71, dtype: int64)
# (72, group1    18288648
# group2    18414590
# weight           1
# Name: 72, dtype: int64)
# (73, group1    20064276
# group2     1358081
# weight           1
# Name: 73, dtype: int64)
# (74, group1    20064276
# group2     6928642
# weight           2
# Name: 74, dtype: int64)
# (75, group1    20064276
# group2    18456837
# weight           1
# Name: 75, dtype: int64)
# (76, group1    20064276
# group2    12847372
# weight           1
# Name: 76, dtype: int64)
# (77, group1    20064276
# group2    19728145
# weight           3
# Name: 77, dtype: int64)
# (78, group1    20064276
# group2    19262745
# weight           2
# Name: 78, dtype: int64)
# (79, group1    20064276
# group2    19416348
# weight           1
# Name: 79, dtype: int64)
# (80, group1    20064276
# group2     2520612
# weight           1
# Name: 80, dtype: int64)
# (81, group1    20064276
# group2     1585196
# weight           1
# Name: 81, dtype: int64)
# (82, group1    20064276
# group2    18955830
# weight           2
# Name: 82, dtype: int64)
# (83, group1    20064276
# group2    20181560
# weight           2
# Name: 83, dtype: int64)
# (84, group1    20064276
# group2     3636792
# weight           1
# Name: 84, dtype: int64)
# (85, group1    20064276
# group2      339011
# weight           1
# Name: 85, dtype: int64)
# (86, group1    20064276
# group2     1665349
# weight           1
# Name: 86, dtype: int64)
# (87, group1    20064276
# group2    19049542
# weight           1
# Name: 87, dtype: int64)
# (88, group1    20064276
# group2     1179719
# weight           1
# Name: 88, dtype: int64)
# (89, group1    20064276
# group2     1431882
# weight           1
# Name: 89, dtype: int64)
# (90, group1    20064276
# group2    24584525
# weight           1
# Name: 90, dtype: int64)
# (91, group1    20064276
# group2     1457232
# weight           1
# Name: 91, dtype: int64)
# (92, group1    20064276
# group2     5282132
# weight           2
# Name: 92, dtype: int64)
# (93, group1    20064276
# group2     1371991
# weight           2
# Name: 93, dtype: int64)
# (94, group1    20064276
# group2    21933145
# weight           1
# Name: 94, dtype: int64)
# (95, group1    20064276
# group2    20377949
# weight           1
# Name: 95, dtype: int64)
# (96, group1    20064276
# group2    20129636
# weight           1
# Name: 96, dtype: int64)
# (97, group1    20064276
# group2    19934054
# weight           1
# Name: 97, dtype: int64)
# (98, group1    20064276
# group2    24153712
# weight           1
# Name: 98, dtype: int64)
# (99, group1    20064276
# group2    24811380
# weight           1
# Name: 99, dtype: int64)
# (100, group1    20064276
# group2      929402
# weight           2
# Name: 100, dtype: int64)
# (101, group1    20064276
# group2     1473660
# weight           2
# Name: 101, dtype: int64)
# (102, group1    20064276
# group2     1187715
# weight           2
# Name: 102, dtype: int64)
# (103, group1    20064276
# group2    10426762
# weight           1
# Name: 103, dtype: int64)
# (104, group1    20064276
# group2     1492619
# weight           3
# Name: 104, dtype: int64)
# (105, group1    20064276
# group2    20068490
# weight           1
# Name: 105, dtype: int64)
# (106, group1    20064276
# group2     6230672
# weight           3
# Name: 106, dtype: int64)
# (107, group1    20064276
# group2    19713173
# weight           1
# Name: 107, dtype: int64)
# (108, group1    20064276
# group2    18801828
# weight           1
# Name: 108, dtype: int64)
# (109, group1    20064276
# group2    20186791
# weight           1
# Name: 109, dtype: int64)
# (110, group1    20064276
# group2    23723436
# weight           1
# Name: 110, dtype: int64)
# (111, group1    20064276
# group2    18589616
# weight           1
# Name: 111, dtype: int64)
# (112, group1    20064276
# group2    18297014
# weight           2
# Name: 112, dtype: int64)
# (113, group1    20064276
# group2     4126912
# weight           1
# Name: 113, dtype: int64)
# (114, group1    20064276
# group2    18953664
# weight           1
# Name: 114, dtype: int64)
# (115, group1    20064276
# group2    20384452
# weight           1
# Name: 115, dtype: int64)
# (116, group1    20064276
# group2     1751502
# weight           1
# Name: 116, dtype: int64)
# (117, group1    20064276
# group2    24675279
# weight           1
# Name: 117, dtype: int64)
# (118, group1    20064276
# group2     7699922
# weight           1
# Name: 118, dtype: int64)
# (119, group1    20064276
# group2     6284242
# weight           2
# Name: 119, dtype: int64)
# (120, group1    20064276
# group2     4705492
# weight           1
# Name: 120, dtype: int64)
# (121, group1    20064276
# group2     1576921
# weight           1
# Name: 121, dtype: int64)
# (122, group1    20064276
# group2    11077852
# weight           3
# Name: 122, dtype: int64)
# (123, group1    20064276
# group2    20836828
# weight           1
# Name: 123, dtype: int64)
# (124, group1    20064276
# group2    22197221
# weight           1
# Name: 124, dtype: int64)
# (125, group1    20064276
# group2    22422502
# weight           2
# Name: 125, dtype: int64)
# (126, group1    20064276
# group2    20197351
# weight           1
# Name: 126, dtype: int64)
# (127, group1    20064276
# group2     1642477
# weight           3
# Name: 127, dtype: int64)
# (128, group1    20064276
# group2    18361585
# weight           1
# Name: 128, dtype: int64)
# (129, group1    20064276
# group2    18243826
# weight           2
# Name: 129, dtype: int64)
# (130, group1    20064276
# group2    14566132
# weight           1
# Name: 130, dtype: int64)
# (131, group1    20064276
# group2    11776502
# weight           1
# Name: 131, dtype: int64)
# (132, group1    20064276
# group2     6629622
# weight           3
# Name: 132, dtype: int64)
# (133, group1    20064276
# group2    18256892
# weight           1
# Name: 133, dtype: int64)
# (134, group1    20064276
# group2    18414590
# weight           1
# Name: 134, dtype: int64)
# (135, group1    19275797
# group2      535553
# weight           1
# Name: 135, dtype: int64)
# (136, group1    19275797
# group2    16487812
# weight           2
# Name: 136, dtype: int64)
# (137, group1    19275797
# group2    18456837
# weight           1
# Name: 137, dtype: int64)
# (138, group1    19275797
# group2    11862932
# weight           1
# Name: 138, dtype: int64)
# (139, group1    19275797
# group2    18494105
# weight           1
# Name: 139, dtype: int64)
# (140, group1    19275797
# group2     4631582
# weight           1
# Name: 140, dtype: int64)
# (141, group1    19275797
# group2     1728035
# weight           1
# Name: 141, dtype: int64)
# (142, group1    19275797
# group2    20186791
# weight           1
# Name: 142, dtype: int64)
# (143, group1    19275797
# group2     6641192
# weight           1
# Name: 143, dtype: int64)
# (144, group1    19275797
# group2     7836842
# weight           1
# Name: 144, dtype: int64)
# (145, group1    19275797
# group2    19997487
# weight           1
# Name: 145, dtype: int64)
# (146, group1    19275797
# group2    17467312
# weight           1
# Name: 146, dtype: int64)
# (147, group1    19275797
# group2      405938
# weight           1
# Name: 147, dtype: int64)
# (148, group1    19275797
# group2    18855476
# weight           1
# Name: 148, dtype: int64)
# (149, group1    19275797
# group2     9376702
# weight           1
# Name: 149, dtype: int64)
# (150, group1    19275797
# group2    10178242
# weight           1
# Name: 150, dtype: int64)
# (151, group1    19275797
# group2    19904711
# weight           1
# Name: 151, dtype: int64)
# (152, group1    19275797
# group2      227528
# weight           1
# Name: 152, dtype: int64)
# (153, group1    19275797
# group2    14546632
# weight           1
# Name: 153, dtype: int64)
# (154, group1    19275797
# group2    19030621
# weight           1
# Name: 154, dtype: int64)
# (155, group1    19275797
# group2    10016242
# weight           1
# Name: 155, dtype: int64)
# (156, group1    19275797
# group2     7130232
# weight           1
# Name: 156, dtype: int64)
# (157, group1    20135961
# group2    18562307
# weight           1
# Name: 157, dtype: int64)
# (158, group1    20135961
# group2    11375762
# weight           1
# Name: 158, dtype: int64)
# (159, group1    20135961
# group2    21390741
# weight           1
# Name: 159, dtype: int64)
# (160, group1    20135961
# group2    19713173
# weight           3
# Name: 160, dtype: int64)
# (161, group1    20135961
# group2    19249559
# weight           1
# Name: 161, dtype: int64)
# (162, group1    20135961
# group2    18506072
# weight           3
# Name: 162, dtype: int64)
# (163, group1    20135961
# group2    19847832
# weight           1
# Name: 163, dtype: int64)
# (164, group1    20135961
# group2     3870752
# weight           1
# Name: 164, dtype: int64)
# (165, group1    20135961
# group2     6190702
# weight           1
# Name: 165, dtype: int64)
# (166, group1    20135961
# group2    19828207
# weight           2
# Name: 166, dtype: int64)
# (167, group1    20135961
# group2     8908602
# weight           1
# Name: 167, dtype: int64)
# (168, group1     3870752
# group2    16487812
# weight           1
# Name: 168, dtype: int64)
# (169, group1     3870752
# group2    19728145
# weight           1
# Name: 169, dtype: int64)
# (170, group1     3870752
# group2    18494105
# weight           1
# Name: 170, dtype: int64)
# (171, group1     3870752
# group2    20186791
# weight           1
# Name: 171, dtype: int64)
# (172, group1    3870752
# group2    1451826
# weight          1
# Name: 172, dtype: int64)
# (173, group1     3870752
# group2    16447162
# weight           1
# Name: 173, dtype: int64)
# (174, group1    3870752
# group2    1526075
# weight          3
# Name: 174, dtype: int64)
# (175, group1     3870752
# group2    18180033
# weight           1
# Name: 175, dtype: int64)
# (176, group1    3870752
# group2     339011
# weight          1
# Name: 176, dtype: int64)
# (177, group1     3870752
# group2    14649032
# weight           1
# Name: 177, dtype: int64)
# (178, group1    3870752
# group2    2542802
# weight          1
# Name: 178, dtype: int64)
# (179, group1     3870752
# group2    18506072
# weight           2
# Name: 179, dtype: int64)
# (180, group1     3870752
# group2    11625832
# weight           1
# Name: 180, dtype: int64)
# (181, group1    3870752
# group2     526316
# weight          1
# Name: 181, dtype: int64)
# (182, group1     3870752
# group2    16877932
# weight           1
# Name: 182, dtype: int64)
# (183, group1    21143591
# group2     1772099
# weight           1
# Name: 183, dtype: int64)
# (184, group1    21143591
# group2      227528
# weight           1
# Name: 184, dtype: int64)
# (185, group1    21143591
# group2    20806988
# weight           1
# Name: 185, dtype: int64)
# (186, group1    21143591
# group2    19728145
# weight           1
# Name: 186, dtype: int64)
# (187, group1    21143591
# group2     4705492
# weight           1
# Name: 187, dtype: int64)
# (188, group1    21143591
# group2    21933145
# weight           1
# Name: 188, dtype: int64)
# (189, group1    21143591
# group2    21174496
# weight           1
# Name: 189, dtype: int64)
# (190, group1    21143591
# group2    22730657
# weight           1
# Name: 190, dtype: int64)
# (191, group1    21143591
# group2    20336043
# weight           5
# Name: 191, dtype: int64)
# (192, group1    21143591
# group2    15552112
# weight           1
# Name: 192, dtype: int64)
# (193, group1    21143591
# group2    18243826
# weight           1
# Name: 193, dtype: int64)
# (194, group1    21143591
# group2    18297014
# weight           1
# Name: 194, dtype: int64)
# (195, group1    21143591
# group2    18955830
# weight           1
# Name: 195, dtype: int64)
# (196, group1    1585196
# group2    1102353
# weight          7
# Name: 196, dtype: int64)
# (197, group1     1585196
# group2    23816722
# weight           1
# Name: 197, dtype: int64)
# (198, group1    1585196
# group2    2556962
# weight          1
# Name: 198, dtype: int64)
# (199, group1    1585196
# group2    2520612
# weight          1
# Name: 199, dtype: int64)
# (200, group1     1585196
# group2    20583464
# weight           1
# Name: 200, dtype: int64)
# (201, group1    1585196
# group2    6641192
# weight          1
# Name: 201, dtype: int64)
# (202, group1     1585196
# group2    18955830
# weight          10
# Name: 202, dtype: int64)
# (203, group1     1585196
# group2    20181560
# weight           7
# Name: 203, dtype: int64)
# (204, group1     1585196
# group2    18567736
# weight           1
# Name: 204, dtype: int64)
# (205, group1     1585196
# group2    22023226
# weight           1
# Name: 205, dtype: int64)
# (206, group1    1585196
# group2     339011
# weight         44
# Name: 206, dtype: int64)
# (207, group1    1585196
# group2    1772099
# weight          2
# Name: 207, dtype: int64)
# (208, group1    1585196
# group2    1179719
# weight          1
# Name: 208, dtype: int64)
# (209, group1    1585196
# group2    1417288
# weight          2
# Name: 209, dtype: int64)
# (210, group1     1585196
# group2    18604107
# weight           1
# Name: 210, dtype: int64)
# (211, group1    1585196
# group2     168014
# weight          1
# Name: 211, dtype: int64)
# (212, group1     1585196
# group2    13560402
# weight           1
# Name: 212, dtype: int64)
# (213, group1     1585196
# group2    19030621
# weight           2
# Name: 213, dtype: int64)
# (214, group1     1585196
# group2    16477792
# weight           2
# Name: 214, dtype: int64)
# (215, group1     1585196
# group2    20166757
# weight           1
# Name: 215, dtype: int64)
# (216, group1    1585196
# group2    1507431
# weight          3
# Name: 216, dtype: int64)
# (217, group1    1585196
# group2    6190702
# weight          1
# Name: 217, dtype: int64)
# (218, group1     1585196
# group2    15552112
# weight           2
# Name: 218, dtype: int64)
# (219, group1     1585196
# group2    24039540
# weight           1
# Name: 219, dtype: int64)
# (220, group1    1585196
# group2    1292918
# weight          2
# Name: 220, dtype: int64)
# (221, group1    1585196
# group2     929402
# weight          8
# Name: 221, dtype: int64)
# (222, group1    1585196
# group2    1473660
# weight          1
# Name: 222, dtype: int64)
# (223, group1    1585196
# group2    1240194
# weight          1
# Name: 223, dtype: int64)
# (224, group1    1585196
# group2     541319
# weight          1
# Name: 224, dtype: int64)
# (225, group1     1585196
# group2    19708553
# weight           1
# Name: 225, dtype: int64)
# (226, group1     1585196
# group2    19824779
# weight           1
# Name: 226, dtype: int64)
# (227, group1    1585196
# group2    6230672
# weight          3
# Name: 227, dtype: int64)
# (228, group1    1585196
# group2    1776274
# weight          2
# Name: 228, dtype: int64)
# (229, group1     1585196
# group2    18795154
# weight           1
# Name: 229, dtype: int64)
# (230, group1     1585196
# group2    19713173
# weight           9
# Name: 230, dtype: int64)
# (231, group1     1585196
# group2    18494105
# weight           2
# Name: 231, dtype: int64)
# (232, group1     1585196
# group2    22374557
# weight           1
# Name: 232, dtype: int64)
# (233, group1    1585196
# group2     252576
# weight          4
# Name: 233, dtype: int64)
# (234, group1     1585196
# group2    11131552
# weight           2
# Name: 234, dtype: int64)
# (235, group1     1585196
# group2    20493986
# weight           1
# Name: 235, dtype: int64)
# (236, group1     1585196
# group2    20186791
# weight           1
# Name: 236, dtype: int64)
# (237, group1    1585196
# group2    1324203
# weight          2
# Name: 237, dtype: int64)
# (238, group1     1585196
# group2    19828398
# weight           2
# Name: 238, dtype: int64)
# (239, group1     1585196
# group2    15335602
# weight           1
# Name: 239, dtype: int64)
# (240, group1     1585196
# group2    18297014
# weight           3
# Name: 240, dtype: int64)
# (241, group1    1585196
# group2    1307837
# weight          1
# Name: 241, dtype: int64)
# (242, group1    1585196
# group2    6707902
# weight          2
# Name: 242, dtype: int64)
# (243, group1    1585196
# group2    4126912
# weight          1
# Name: 243, dtype: int64)
# (244, group1     1585196
# group2    20384452
# weight           1
# Name: 244, dtype: int64)
# (245, group1     1585196
# group2    16062152
# weight           1
# Name: 245, dtype: int64)
# (246, group1    1585196
# group2    4705492
# weight          1
# Name: 246, dtype: int64)
# (247, group1     1585196
# group2    11077852
# weight           2
# Name: 247, dtype: int64)
# (248, group1     1585196
# group2    21174496
# weight           3
# Name: 248, dtype: int64)
# (249, group1     1585196
# group2    25397992
# weight           1
# Name: 249, dtype: int64)
# (250, group1     1585196
# group2    18243826
# weight          14
# Name: 250, dtype: int64)
# (251, group1    1585196
# group2    1505523
# weight          1
# Name: 251, dtype: int64)
# (252, group1    1585196
# group2    6629622
# weight          3
# Name: 252, dtype: int64)
# (253, group1     1585196
# group2    15297782
# weight           1
# Name: 253, dtype: int64)
# (254, group1    1585196
# group2    1358081
# weight          1
# Name: 254, dtype: int64)
# (255, group1    1585196
# group2    6928642
# weight          1
# Name: 255, dtype: int64)
# (256, group1     1585196
# group2    18562307
# weight           3
# Name: 256, dtype: int64)
# (257, group1     1585196
# group2    18495240
# weight          30
# Name: 257, dtype: int64)
# (258, group1     1585196
# group2    12847372
# weight           7
# Name: 258, dtype: int64)
# (259, group1     1585196
# group2    19728145
# weight          18
# Name: 259, dtype: int64)
# (260, group1     1585196
# group2    19416348
# weight           1
# Name: 260, dtype: int64)
# (261, group1     1585196
# group2    18425641
# weight           1
# Name: 261, dtype: int64)
# (262, group1     1585196
# group2    20931376
# weight           1
# Name: 262, dtype: int64)
# (263, group1    1585196
# group2    1526075
# weight          1
# Name: 263, dtype: int64)
# (264, group1     1585196
# group2    20757821
# weight           1
# Name: 264, dtype: int64)
# (265, group1    1585196
# group2    5282132
# weight          2
# Name: 265, dtype: int64)
# (266, group1     1585196
# group2    19266390
# weight           3
# Name: 266, dtype: int64)
# (267, group1    1585196
# group2    1371991
# weight          3
# Name: 267, dtype: int64)
# (268, group1     1585196
# group2    18506072
# weight           6
# Name: 268, dtype: int64)
# (269, group1     1585196
# group2    18286946
# weight           1
# Name: 269, dtype: int64)
# (270, group1     1585196
# group2    20129636
# weight           1
# Name: 270, dtype: int64)
# (271, group1     1585196
# group2    19934054
# weight           1
# Name: 271, dtype: int64)
# (272, group1     1585196
# group2    11625832
# weight           3
# Name: 272, dtype: int64)
# (273, group1     1585196
# group2    18529135
# weight           1
# Name: 273, dtype: int64)
# (274, group1    1585196
# group2    1763190
# weight          3
# Name: 274, dtype: int64)
# (275, group1     1585196
# group2    18571126
# weight           1
# Name: 275, dtype: int64)
# (276, group1    1585196
# group2    1187715
# weight          6
# Name: 276, dtype: int64)
# (277, group1     1585196
# group2    16487812
# weight           2
# Name: 277, dtype: int64)
# (278, group1     1585196
# group2    24803205
# weight           2
# Name: 278, dtype: int64)
# (279, group1     1585196
# group2    20586888
# weight           1
# Name: 279, dtype: int64)
# (280, group1    1585196
# group2    1665418
# weight          1
# Name: 280, dtype: int64)
# (281, group1    1585196
# group2    6335372
# weight          1
# Name: 281, dtype: int64)
# (282, group1     1585196
# group2    11862932
# weight           1
# Name: 282, dtype: int64)
# (283, group1     1585196
# group2    19249559
# weight           3
# Name: 283, dtype: int64)
# (284, group1     1585196
# group2    22730657
# weight           2
# Name: 284, dtype: int64)
# (285, group1     1585196
# group2    19218850
# weight           1
# Name: 285, dtype: int64)
# (286, group1     1585196
# group2    21837219
# weight           1
# Name: 286, dtype: int64)
# (287, group1     1585196
# group2    20336043
# weight           4
# Name: 287, dtype: int64)
# (288, group1     1585196
# group2    18314669
# weight           1
# Name: 288, dtype: int64)
# (289, group1     1585196
# group2    18589616
# weight           3
# Name: 289, dtype: int64)
# (290, group1     1585196
# group2    18314164
# weight           1
# Name: 290, dtype: int64)
# (291, group1    1585196
# group2    9376702
# weight          1
# Name: 291, dtype: int64)
# (292, group1    1585196
# group2    1751502
# weight          1
# Name: 292, dtype: int64)
# (293, group1     1585196
# group2    18944977
# weight           1
# Name: 293, dtype: int64)
# (294, group1     1585196
# group2    18616278
# weight           1
# Name: 294, dtype: int64)
# (295, group1    1585196
# group2    1349592
# weight          7
# Name: 295, dtype: int64)
# (296, group1     1585196
# group2    17872862
# weight           1
# Name: 296, dtype: int64)
# (297, group1     1585196
# group2    18573279
# weight           1
# Name: 297, dtype: int64)
# (298, group1     1585196
# group2    23515107
# weight           2
# Name: 298, dtype: int64)
# (299, group1     1585196
# group2    22197221
# weight           8
# Name: 299, dtype: int64)
# (300, group1     1585196
# group2    19443174
# weight           2
# Name: 300, dtype: int64)
# (301, group1     1585196
# group2    20807142
# weight           1
# Name: 301, dtype: int64)
# (302, group1     1585196
# group2    22422502
# weight           1
# Name: 302, dtype: int64)
# (303, group1    1585196
# group2     526316
# weight          1
# Name: 303, dtype: int64)
# (304, group1    1585196
# group2    1642477
# weight          2
# Name: 304, dtype: int64)
# (305, group1     1585196
# group2    22736876
# weight           1
# Name: 305, dtype: int64)
# (306, group1     1585196
# group2    19828207
# weight           2
# Name: 306, dtype: int64)
# (307, group1     1585196
# group2    10016242
# weight           2
# Name: 307, dtype: int64)
# (308, group1    1585196
# group2    5327862
# weight          1
# Name: 308, dtype: int64)
# (309, group1     1585196
# group2    16548342
# weight           1
# Name: 309, dtype: int64)
# (310, group1    1585196
# group2      47094
# weight          1
# Name: 310, dtype: int64)
# (311, group1     1585196
# group2    18414590
# weight           1
# Name: 311, dtype: int64)
# (312, group1    1179719
# group2     535553
# weight          1
# Name: 312, dtype: int64)
# (313, group1     1179719
# group2    18798102
# weight           2
# Name: 313, dtype: int64)
# (314, group1    1179719
# group2     191516
# weight          4
# Name: 314, dtype: int64)
# (315, group1    1179719
# group2     788001
# weight          2
# Name: 315, dtype: int64)
# (316, group1    1179719
# group2    1728035
# weight          1
# Name: 316, dtype: int64)
# (317, group1     1179719
# group2    18855476
# weight           1
# Name: 317, dtype: int64)
# (318, group1     1179719
# group2    18955830
# weight           5
# Name: 318, dtype: int64)
# (319, group1     1179719
# group2    11294262
# weight           1
# Name: 319, dtype: int64)
# (320, group1     1179719
# group2    20181560
# weight           1
# Name: 320, dtype: int64)
# (321, group1    1179719
# group2     339011
# weight          2
# Name: 321, dtype: int64)
# (322, group1    1179719
# group2     168014
# weight          1
# Name: 322, dtype: int64)
# (323, group1     1179719
# group2    13560402
# weight           1
# Name: 323, dtype: int64)
# (324, group1     1179719
# group2    19030621
# weight           1
# Name: 324, dtype: int64)
# (325, group1    1179719
# group2    7130232
# weight          1
# Name: 325, dtype: int64)
# (326, group1    1179719
# group2     929402
# weight          1
# Name: 326, dtype: int64)
# (327, group1    1179719
# group2     710272
# weight          2
# Name: 327, dtype: int64)
# (328, group1     1179719
# group2    19713173
# weight           1
# Name: 328, dtype: int64)
# (329, group1     1179719
# group2    17487002
# weight           2
# Name: 329, dtype: int64)
# (330, group1     1179719
# group2    22374557
# weight           1
# Name: 330, dtype: int64)
# (331, group1     1179719
# group2    20186791
# weight           1
# Name: 331, dtype: int64)
# (332, group1    1179719
# group2    7836842
# weight          2
# Name: 332, dtype: int64)
# (333, group1    1179719
# group2    1324203
# weight          4
# Name: 333, dtype: int64)
# (334, group1     1179719
# group2    19828398
# weight           1
# Name: 334, dtype: int64)
# (335, group1     1179719
# group2    15335602
# weight           1
# Name: 335, dtype: int64)
# (336, group1     1179719
# group2    18297014
# weight           1
# Name: 336, dtype: int64)
# (337, group1    1179719
# group2    1578685
# weight          1
# Name: 337, dtype: int64)
# (338, group1     1179719
# group2    10178242
# weight           1
# Name: 338, dtype: int64)
# (339, group1     1179719
# group2    19556549
# weight           1
# Name: 339, dtype: int64)
# (340, group1     1179719
# group2    16062152
# weight           1
# Name: 340, dtype: int64)
# (341, group1    1179719
# group2     227528
# weight          2
# Name: 341, dtype: int64)
# (342, group1     1179719
# group2    18660552
# weight           1
# Name: 342, dtype: int64)
# (343, group1     1179719
# group2    11077852
# weight           1
# Name: 343, dtype: int64)
# (344, group1    1179719
# group2    7263452
# weight          1
# Name: 344, dtype: int64)
# (345, group1     1179719
# group2    25397992
# weight           1
# Name: 345, dtype: int64)
# (346, group1     1179719
# group2    18243826
# weight           1
# Name: 346, dtype: int64)
# (347, group1     1179719
# group2    14566132
# weight           2
# Name: 347, dtype: int64)
# (348, group1     1179719
# group2    15297782
# weight           1
# Name: 348, dtype: int64)
# (349, group1    1179719
# group2    2496252
# weight          1
# Name: 349, dtype: int64)
# (350, group1    1179719
# group2    6928642
# weight          1
# Name: 350, dtype: int64)
# (351, group1     1179719
# group2    18562307
# weight           2
# Name: 351, dtype: int64)
# (352, group1     1179719
# group2    12847372
# weight           1
# Name: 352, dtype: int64)
# (353, group1     1179719
# group2    19728145
# weight           1
# Name: 353, dtype: int64)
# (354, group1     1179719
# group2    19262745
# weight           1
# Name: 354, dtype: int64)
# (355, group1    1179719
# group2    1169709
# weight          1
# Name: 355, dtype: int64)
# (356, group1     1179719
# group2    19997487
# weight           1
# Name: 356, dtype: int64)
# (357, group1    1179719
# group2    1526075
# weight          1
# Name: 357, dtype: int64)
# (358, group1    1179719
# group2    1078077
# weight          1
# Name: 358, dtype: int64)
# (359, group1    1179719
# group2    5282132
# weight          1
# Name: 359, dtype: int64)
# (360, group1    1179719
# group2    1371991
# weight          3
# Name: 360, dtype: int64)
# (361, group1     1179719
# group2    18506072
# weight           4
# Name: 361, dtype: int64)
# (362, group1     1179719
# group2    18286946
# weight           1
# Name: 362, dtype: int64)
# (363, group1    1179719
# group2    5618532
# weight          1
# Name: 363, dtype: int64)
# (364, group1     1179719
# group2    19934054
# weight           1
# Name: 364, dtype: int64)
# (365, group1     1179719
# group2    11625832
# weight           1
# Name: 365, dtype: int64)
# (366, group1    1179719
# group2    1763190
# weight          1
# Name: 366, dtype: int64)
# (367, group1     1179719
# group2    18517376
# weight           1
# Name: 367, dtype: int64)
# (368, group1    1179719
# group2    1187715
# weight          4
# Name: 368, dtype: int64)
# (369, group1     1179719
# group2    16487812
# weight           1
# Name: 369, dtype: int64)
# (370, group1     1179719
# group2    10426762
# weight           1
# Name: 370, dtype: int64)
# (371, group1     1179719
# group2    23674770
# weight           3
# Name: 371, dtype: int64)
# (372, group1     1179719
# group2    19249559
# weight           1
# Name: 372, dtype: int64)
# (373, group1     1179719
# group2    18923420
# weight           1
# Name: 373, dtype: int64)
# (374, group1     1179719
# group2    22730657
# weight           1
# Name: 374, dtype: int64)
# (375, group1     1179719
# group2    11938732
# weight           1
# Name: 375, dtype: int64)
# (376, group1     1179719
# group2    18589616
# weight           1
# Name: 376, dtype: int64)
# (377, group1     1179719
# group2    18476981
# weight           1
# Name: 377, dtype: int64)
# (378, group1    1179719
# group2    9376702
# weight          1
# Name: 378, dtype: int64)
# (379, group1     1179719
# group2    23595967
# weight           1
# Name: 379, dtype: int64)
# (380, group1     1179719
# group2    19100119
# weight           1
# Name: 380, dtype: int64)
# (381, group1     1179719
# group2    20807142
# weight           3
# Name: 381, dtype: int64)
# (382, group1     1179719
# group2    25587693
# weight           2
# Name: 382, dtype: int64)
# (383, group1    1179719
# group2    1642477
# weight          1
# Name: 383, dtype: int64)
# (384, group1     1179719
# group2    10016242
# weight           1
# Name: 384, dtype: int64)
# (385, group1    1179719
# group2    5327862
# weight          7
# Name: 385, dtype: int64)
# (386, group1    1417288
# group2    1728035
# weight          1
# Name: 386, dtype: int64)
# (387, group1     1417288
# group2    19528743
# weight           1
# Name: 387, dtype: int64)
# (388, group1     1417288
# group2    18955830
# weight           1
# Name: 388, dtype: int64)
# (389, group1     1417288
# group2    22023226
# weight           1
# Name: 389, dtype: int64)
# (390, group1    1417288
# group2    8540732
# weight          1
# Name: 390, dtype: int64)
# (391, group1    1417288
# group2    1772099
# weight          1
# Name: 391, dtype: int64)
# (392, group1    1417288
# group2     339011
# weight          1
# Name: 392, dtype: int64)
# (393, group1     1417288
# group2    16607822
# weight           1
# Name: 393, dtype: int64)
# (394, group1    1417288
# group2     168014
# weight          1
# Name: 394, dtype: int64)
# (395, group1     1417288
# group2    15552112
# weight           1
# Name: 395, dtype: int64)
# (396, group1    1417288
# group2    1292918
# weight          1
# Name: 396, dtype: int64)
# (397, group1    1417288
# group2     929402
# weight          1
# Name: 397, dtype: int64)
# (398, group1     1417288
# group2    18672773
# weight           1
# Name: 398, dtype: int64)
# (399, group1    1417288
# group2     541319
# weight          9
# Name: 399, dtype: int64)
# (400, group1     1417288
# group2    19708553
# weight           1
# Name: 400, dtype: int64)
# (401, group1    1417288
# group2    1492619
# weight          1
# Name: 401, dtype: int64)
# (402, group1    1417288
# group2    1776274
# weight          3
# Name: 402, dtype: int64)
# (403, group1     1417288
# group2    18795154
# weight           1
# Name: 403, dtype: int64)
# (404, group1    1417288
# group2    7836842
# weight          1
# Name: 404, dtype: int64)
# (405, group1     1417288
# group2    18297014
# weight           1
# Name: 405, dtype: int64)
# (406, group1    1417288
# group2    1578685
# weight          1
# Name: 406, dtype: int64)
# (407, group1    1417288
# group2    4126912
# weight          3
# Name: 407, dtype: int64)
# (408, group1     1417288
# group2    16062152
# weight           1
# Name: 408, dtype: int64)
# (409, group1     1417288
# group2    19680459
# weight           1
# Name: 409, dtype: int64)
# (410, group1    1417288
# group2    4705492
# weight          3
# Name: 410, dtype: int64)
# (411, group1     1417288
# group2    11077852
# weight           1
# Name: 411, dtype: int64)
# (412, group1    1417288
# group2    8771812
# weight          1
# Name: 412, dtype: int64)
# (413, group1     1417288
# group2    22808815
# weight           1
# Name: 413, dtype: int64)
# (414, group1     1417288
# group2    15297782
# weight           1
# Name: 414, dtype: int64)
# (415, group1    1417288
# group2    2496252
# weight          1
# Name: 415, dtype: int64)
# (416, group1     1417288
# group2    21715712
# weight           1
# Name: 416, dtype: int64)
# (417, group1    1417288
# group2    1358081
# weight          2
# Name: 417, dtype: int64)
# (418, group1     1417288
# group2    18562307
# weight           1
# Name: 418, dtype: int64)
# (419, group1     1417288
# group2    18456837
# weight           1
# Name: 419, dtype: int64)
# (420, group1     1417288
# group2    19728145
# weight           1
# Name: 420, dtype: int64)
# (421, group1     1417288
# group2    19416348
# weight           1
# Name: 421, dtype: int64)
# (422, group1    1417288
# group2    1274150
# weight          1
# Name: 422, dtype: int64)
# (423, group1     1417288
# group2    18425641
# weight           1
# Name: 423, dtype: int64)
# (424, group1    1417288
# group2    1169709
# weight          2
# Name: 424, dtype: int64)
# (425, group1    1417288
# group2    4063542
# weight          1
# Name: 425, dtype: int64)
# (426, group1    1417288
# group2    1354051
# weight          1
# Name: 426, dtype: int64)
# (427, group1     1417288
# group2    11626822
# weight           1
# Name: 427, dtype: int64)
# (428, group1    1417288
# group2    5282132
# weight          1
# Name: 428, dtype: int64)
# (429, group1     1417288
# group2    19266390
# weight           1
# Name: 429, dtype: int64)
# (430, group1     1417288
# group2    18506072
# weight           2
# Name: 430, dtype: int64)
# (431, group1     1417288
# group2    18529135
# weight           1
# Name: 431, dtype: int64)
# (432, group1     1417288
# group2    14396812
# weight           1
# Name: 432, dtype: int64)
# (433, group1     1417288
# group2    21837219
# weight           1
# Name: 433, dtype: int64)
# (434, group1    1417288
# group2    3376042
# weight          2
# Name: 434, dtype: int64)
# (435, group1     1417288
# group2    18314669
# weight           2
# Name: 435, dtype: int64)
# (436, group1    1417288
# group2     711599
# weight          1
# Name: 436, dtype: int64)
# (437, group1     1417288
# group2    23112117
# weight           1
# Name: 437, dtype: int64)
# (438, group1     1417288
# group2    18977219
# weight           1
# Name: 438, dtype: int64)
# (439, group1    1417288
# group2    1349592
# weight          1
# Name: 439, dtype: int64)
# (440, group1    1417288
# group2    1576921
# weight          1
# Name: 440, dtype: int64)
# (441, group1    1417288
# group2    1498076
# weight          1
# Name: 441, dtype: int64)
# (442, group1     1417288
# group2    18573279
# weight           2
# Name: 442, dtype: int64)
# (443, group1    1417288
# group2     204767
# weight          1
# Name: 443, dtype: int64)
# (444, group1     1417288
# group2    20348898
# weight           1
# Name: 444, dtype: int64)
# (445, group1     1417288
# group2    22197221
# weight           1
# Name: 445, dtype: int64)
# (446, group1     1417288
# group2    19654655
# weight           1
# Name: 446, dtype: int64)
# (447, group1    18604107
# group2      339011
# weight           1
# Name: 447, dtype: int64)
# (448, group1    18604107
# group2    18495240
# weight           1
# Name: 448, dtype: int64)
# (449, group1    18604107
# group2     1102353
# weight           1
# Name: 449, dtype: int64)
# (450, group1    18604107
# group2    19030621
# weight           1
# Name: 450, dtype: int64)
# (451, group1    18604107
# group2      929402
# weight           4
# Name: 451, dtype: int64)
# (452, group1    18604107
# group2     1473660
# weight           1
# Name: 452, dtype: int64)
# (453, group1     168014
# group2    1358081
# weight          2
# Name: 453, dtype: int64)
# (454, group1    168014
# group2    981249
# weight         1
# Name: 454, dtype: int64)
# (455, group1      168014
# group2    19728145
# weight           3
# Name: 455, dtype: int64)
# (456, group1      168014
# group2    19416348
# weight           1
# Name: 456, dtype: int64)
# (457, group1     168014
# group2    1728035
# weight          2
# Name: 457, dtype: int64)
# (458, group1     168014
# group2    1169709
# weight          3
# Name: 458, dtype: int64)
# (459, group1     168014
# group2    1451826
# weight          1
# Name: 459, dtype: int64)
# (460, group1     168014
# group2    1697586
# weight          1
# Name: 460, dtype: int64)
# (461, group1      168014
# group2    18955830
# weight           1
# Name: 461, dtype: int64)
# (462, group1     168014
# group2    1526075
# weight          1
# Name: 462, dtype: int64)
# (463, group1     168014
# group2    1078077
# weight          1
# Name: 463, dtype: int64)
# (464, group1     168014
# group2    1354051
# weight          1
# Name: 464, dtype: int64)
# (465, group1     168014
# group2    1457232
# weight          1
# Name: 465, dtype: int64)
# (466, group1      168014
# group2    13560402
# weight           1
# Name: 466, dtype: int64)
# (467, group1     168014
# group2    5282132
# weight          1
# Name: 467, dtype: int64)
# (468, group1      168014
# group2    18677333
# weight           1
# Name: 468, dtype: int64)
# (469, group1      168014
# group2    18506072
# weight           2
# Name: 469, dtype: int64)
# (470, group1      168014
# group2    20129636
# weight           1
# Name: 470, dtype: int64)
# (471, group1      168014
# group2    20440175
# weight           3
# Name: 471, dtype: int64)
# (472, group1      168014
# group2    24039540
# weight           1
# Name: 472, dtype: int64)
# (473, group1    168014
# group2    929402
# weight         1
# Name: 473, dtype: int64)
# (474, group1     168014
# group2    1473660
# weight          1
# Name: 474, dtype: int64)
# (475, group1      168014
# group2    18517376
# weight           1
# Name: 475, dtype: int64)
# (476, group1    168014
# group2    710272
# weight         1
# Name: 476, dtype: int64)
# (477, group1     168014
# group2    1187715
# weight          2
# Name: 477, dtype: int64)
# (478, group1      168014
# group2    16487812
# weight           2
# Name: 478, dtype: int64)
# (479, group1      168014
# group2    18821254
# weight           1
# Name: 479, dtype: int64)
# (480, group1    168014
# group2    541319
# weight         5
# Name: 480, dtype: int64)
# (481, group1     168014
# group2    1492619
# weight          1
# Name: 481, dtype: int64)
# (482, group1      168014
# group2    20182158
# weight           1
# Name: 482, dtype: int64)
# (483, group1     168014
# group2    1776274
# weight          2
# Name: 483, dtype: int64)
# (484, group1      168014
# group2    18494105
# weight           1
# Name: 484, dtype: int64)
# (485, group1      168014
# group2    17487002
# weight           1
# Name: 485, dtype: int64)
# (486, group1      168014
# group2    22374557
# weight           1
# Name: 486, dtype: int64)
# (487, group1      168014
# group2    22730657
# weight           1
# Name: 487, dtype: int64)
# (488, group1      168014
# group2    21837219
# weight           1
# Name: 488, dtype: int64)
# (489, group1      168014
# group2    18801828
# weight           1
# Name: 489, dtype: int64)
# (490, group1     168014
# group2    3376042
# weight          1
# Name: 490, dtype: int64)
# (491, group1      168014
# group2    20336043
# weight           1
# Name: 491, dtype: int64)
# (492, group1     168014
# group2    1324203
# weight          1
# Name: 492, dtype: int64)
# (493, group1      168014
# group2    15335602
# weight           1
# Name: 493, dtype: int64)
# (494, group1      168014
# group2    18297014
# weight           2
# Name: 494, dtype: int64)
# (495, group1     168014
# group2    4126912
# weight          1
# Name: 495, dtype: int64)
# (496, group1      168014
# group2    18180033
# weight           1
# Name: 496, dtype: int64)
# (497, group1    168014
# group2    227528
# weight         1
# Name: 497, dtype: int64)
# (498, group1     168014
# group2    1751502
# weight          1
# Name: 498, dtype: int64)
# (499, group1      168014
# group2    11077852
# weight           1
# Name: 499, dtype: int64)
# (500, group1     168014
# group2    8771812
# weight          1
# Name: 500, dtype: int64)
# (501, group1      168014
# group2    19198182
# weight           1
# Name: 501, dtype: int64)
# (502, group1    168014
# group2    526316
# weight         1
# Name: 502, dtype: int64)
# (503, group1     168014
# group2    1642477
# weight          1
# Name: 503, dtype: int64)
# (504, group1      168014
# group2    18361585
# weight           1
# Name: 504, dtype: int64)
# (505, group1      168014
# group2    18232817
# weight           1
# Name: 505, dtype: int64)
# (506, group1      168014
# group2    18243826
# weight           1
# Name: 506, dtype: int64)
# (507, group1     168014
# group2    6629622
# weight          1
# Name: 507, dtype: int64)
# (508, group1    168014
# group2     47094
# weight         1
# Name: 508, dtype: int64)
# (509, group1    18399311
# group2     6928642
# weight           1
# Name: 509, dtype: int64)
# (510, group1    18399311
# group2    20129636
# weight           1
# Name: 510, dtype: int64)
# (511, group1    18399311
# group2    20384452
# weight           1
# Name: 511, dtype: int64)
# (512, group1    18399311
# group2    20166757
# weight           1
# Name: 512, dtype: int64)
# (513, group1    18399311
# group2     1578685
# weight           1
# Name: 513, dtype: int64)
# (514, group1    18602064
# group2     6928642
# weight           1
# Name: 514, dtype: int64)
# (515, group1    18602064
# group2    18795154
# weight           3
# Name: 515, dtype: int64)
# (516, group1    18602064
# group2    19262745
# weight           1
# Name: 516, dtype: int64)
# (517, group1    18602064
# group2    15552112
# weight           2
# Name: 517, dtype: int64)
# (518, group1    18602064
# group2    18468466
# weight           1
# Name: 518, dtype: int64)
# (519, group1    18602064
# group2    24568502
# weight           2
# Name: 519, dtype: int64)
# (520, group1    18602064
# group2    18592827
# weight           2
# Name: 520, dtype: int64)
# (521, group1    23742545
# group2    19728145
# weight           1
# Name: 521, dtype: int64)
# (522, group1    23742545
# group2      191516
# weight           1
# Name: 522, dtype: int64)
# (523, group1    23742545
# group2    19934054
# weight           1
# Name: 523, dtype: int64)
# (524, group1    23742545
# group2     1324203
# weight           1
# Name: 524, dtype: int64)
# (525, group1    23742545
# group2    18361585
# weight           1
# Name: 525, dtype: int64)
# (526, group1    23742545
# group2    11776502
# weight           1
# Name: 526, dtype: int64)
# (527, group1    23742545
# group2    18297014
# weight           1
# Name: 527, dtype: int64)
# (528, group1    17770582
# group2    24906881
# weight           1
# Name: 528, dtype: int64)
# (529, group1    17770582
# group2    23398017
# weight           1
# Name: 529, dtype: int64)
# (530, group1    17770582
# group2     1358081
# weight           1
# Name: 530, dtype: int64)
# (531, group1    17770582
# group2     7138452
# weight           2
# Name: 531, dtype: int64)
# (532, group1    17770582
# group2    18494105
# weight           1
# Name: 532, dtype: int64)
# (533, group1    17770582
# group2    10016162
# weight           1
# Name: 533, dtype: int64)
# (534, group1    17770582
# group2    21837219
# weight           1
# Name: 534, dtype: int64)
# (535, group1    17770582
# group2     1728035
# weight           1
# Name: 535, dtype: int64)
# (536, group1    17770582
# group2    19277993
# weight           1
# Name: 536, dtype: int64)
# (537, group1    17770582
# group2    18314164
# weight           2
# Name: 537, dtype: int64)
# (538, group1    17770582
# group2     1360698
# weight           1
# Name: 538, dtype: int64)
# (539, group1    17770582
# group2     1078077
# weight           1
# Name: 539, dtype: int64)
# (540, group1    17770582
# group2     9376702
# weight           2
# Name: 540, dtype: int64)
# (541, group1    17770582
# group2     6707902
# weight           1
# Name: 541, dtype: int64)
# (542, group1    17770582
# group2    14546632
# weight           1
# Name: 542, dtype: int64)
# (543, group1    17770582
# group2    13560402
# weight           5
# Name: 543, dtype: int64)
# (544, group1    17770582
# group2    18616278
# weight           2
# Name: 544, dtype: int64)
# (545, group1    17770582
# group2     1498076
# weight           1
# Name: 545, dtype: int64)
# (546, group1    17770582
# group2     8771812
# weight           2
# Name: 546, dtype: int64)
# (547, group1    3047512
# group2    1187715
# weight          3
# Name: 547, dtype: int64)
# (548, group1     3047512
# group2    12847372
# weight           1
# Name: 548, dtype: int64)
# (549, group1     3047512
# group2    19728145
# weight           3
# Name: 549, dtype: int64)
# (550, group1    3047512
# group2    1102353
# weight          1
# Name: 550, dtype: int64)
# (551, group1     3047512
# group2    15770262
# weight           1
# Name: 551, dtype: int64)
# (552, group1     3047512
# group2    20421535
# ...
# group2    18589616
# weight           1
# Name: 6513, dtype: int64)
# (6514, group1    14546632
# group2    14649032
# weight           2
# Name: 6514, dtype: int64)
# (6515, group1    14546632
# group2    18616278
# weight           2
# Name: 6515, dtype: int64)
# (6516, group1    14546632
# group2    19654655
# weight           4
# Name: 6516, dtype: int64)
# (6517, group1    16062152
# group2    14649032
# weight           1
# Name: 6517, dtype: int64)
# (6518, group1    16062152
# group2     2496252
# weight           1
# Name: 6518, dtype: int64)
# (6519, group1    16062152
# group2    18425641
# weight           3
# Name: 6519, dtype: int64)
# (6520, group1    16062152
# group2     8908602
# weight           1
# Name: 6520, dtype: int64)
# (6521, group1    16062152
# group2    18767675
# weight           2
# Name: 6521, dtype: int64)
# (6522, group1    16062152
# group2    23353167
# weight           1
# Name: 6522, dtype: int64)
# (6523, group1    16062152
# group2     1187715
# weight           1
# Name: 6523, dtype: int64)
# (6524, group1    16062152
# group2    23594916
# weight           1
# Name: 6524, dtype: int64)
# (6525, group1    16062152
# group2    18589616
# weight           3
# Name: 6525, dtype: int64)
# (6526, group1    16062152
# group2    17467312
# weight           1
# Name: 6526, dtype: int64)
# (6527, group1    16062152
# group2    18616278
# weight           2
# Name: 6527, dtype: int64)
# (6528, group1    16062152
# group2    20197351
# weight           1
# Name: 6528, dtype: int64)
# (6529, group1    16062152
# group2      526316
# weight           1
# Name: 6529, dtype: int64)
# (6530, group1    16062152
# group2    19654655
# weight           1
# Name: 6530, dtype: int64)
# (6531, group1    14649032
# group2    19728145
# weight           1
# Name: 6531, dtype: int64)
# (6532, group1    14649032
# group2     7700282
# weight           1
# Name: 6532, dtype: int64)
# (6533, group1    14649032
# group2     7151442
# weight           4
# Name: 6533, dtype: int64)
# (6534, group1    14649032
# group2    17467312
# weight           2
# Name: 6534, dtype: int64)
# (6535, group1    14649032
# group2    18589616
# weight           1
# Name: 6535, dtype: int64)
# (6536, group1    14649032
# group2    18616278
# weight           3
# Name: 6536, dtype: int64)
# (6537, group1    14649032
# group2    19654655
# weight           4
# Name: 6537, dtype: int64)
# (6538, group1    25681644
# group2     1187715
# weight           1
# Name: 6538, dtype: int64)
# (6539, group1    25681644
# group2    19728145
# weight           1
# Name: 6539, dtype: int64)
# (6540, group1    25681644
# group2     1371991
# weight           1
# Name: 6540, dtype: int64)
# (6541, group1    25681644
# group2     1642477
# weight           1
# Name: 6541, dtype: int64)
# (6542, group1     2496252
# group2    19728145
# weight           2
# Name: 6542, dtype: int64)
# (6543, group1    2496252
# group2    1371991
# weight          1
# Name: 6543, dtype: int64)
# (6544, group1    2496252
# group2    1187715
# weight          1
# Name: 6544, dtype: int64)
# (6545, group1     2496252
# group2    24850344
# weight           1
# Name: 6545, dtype: int64)
# (6546, group1     2496252
# group2    23515107
# weight           1
# Name: 6546, dtype: int64)
# (6547, group1    2496252
# group2     526316
# weight          1
# Name: 6547, dtype: int64)
# (6548, group1    12588802
# group2     1187715
# weight           2
# Name: 6548, dtype: int64)
# (6549, group1    12588802
# group2     1697586
# weight           1
# Name: 6549, dtype: int64)
# (6550, group1    18495240
# group2    19728145
# weight           4
# Name: 6550, dtype: int64)
# (6551, group1    18495240
# group2     1371991
# weight           1
# Name: 6551, dtype: int64)
# (6552, group1    18495240
# group2     1187715
# weight           3
# Name: 6552, dtype: int64)
# (6553, group1    18495240
# group2    22730657
# weight           1
# Name: 6553, dtype: int64)
# (6554, group1    18495240
# group2    18589616
# weight           1
# Name: 6554, dtype: int64)
# (6555, group1    19728145
# group2    26091301
# weight           1
# Name: 6555, dtype: int64)
# (6556, group1    19728145
# group2     1697586
# weight           1
# Name: 6556, dtype: int64)
# (6557, group1    19728145
# group2     8908602
# weight           4
# Name: 6557, dtype: int64)
# (6558, group1    19728145
# group2     7700282
# weight           3
# Name: 6558, dtype: int64)
# (6559, group1    19728145
# group2     1371991
# weight          12
# Name: 6559, dtype: int64)
# (6560, group1    19728145
# group2    20129636
# weight           2
# Name: 6560, dtype: int64)
# (6561, group1    19728145
# group2     1763190
# weight           2
# Name: 6561, dtype: int64)
# (6562, group1    19728145
# group2    25718653
# weight           1
# Name: 6562, dtype: int64)
# (6563, group1    19728145
# group2     1187715
# weight          18
# Name: 6563, dtype: int64)
# (6564, group1    19728145
# group2    24803205
# weight           6
# Name: 6564, dtype: int64)
# (6565, group1    19728145
# group2    23674770
# weight           2
# Name: 6565, dtype: int64)
# (6566, group1    19728145
# group2    22730657
# weight           1
# Name: 6566, dtype: int64)
# (6567, group1    19728145
# group2    18476981
# weight           3
# Name: 6567, dtype: int64)
# (6568, group1    19728145
# group2    18180033
# weight           1
# Name: 6568, dtype: int64)
# (6569, group1    19728145
# group2    13635532
# weight           1
# Name: 6569, dtype: int64)
# (6570, group1    19728145
# group2     1349592
# weight           3
# Name: 6570, dtype: int64)
# (6571, group1    19728145
# group2     1576921
# weight           6
# Name: 6571, dtype: int64)
# (6572, group1    19728145
# group2    20348898
# weight           1
# Name: 6572, dtype: int64)
# (6573, group1    19728145
# group2      526316
# weight          20
# Name: 6573, dtype: int64)
# (6574, group1    19728145
# group2     1642477
# weight           8
# Name: 6574, dtype: int64)
# (6575, group1    19728145
# group2    19654655
# weight           1
# Name: 6575, dtype: int64)
# (6576, group1    26091301
# group2    22730657
# weight           1
# Name: 6576, dtype: int64)
# (6577, group1    18425641
# group2     8908602
# weight           3
# Name: 6577, dtype: int64)
# (6578, group1    18425641
# group2     7700282
# weight           1
# Name: 6578, dtype: int64)
# (6579, group1    18425641
# group2      255854
# weight           1
# Name: 6579, dtype: int64)
# (6580, group1    18425641
# group2    21245809
# weight           1
# Name: 6580, dtype: int64)
# (6581, group1    18425641
# group2    19822479
# weight           1
# Name: 6581, dtype: int64)
# (6582, group1    18425641
# group2    18589616
# weight           1
# Name: 6582, dtype: int64)
# (6583, group1    18425641
# group2    18616278
# weight           1
# Name: 6583, dtype: int64)
# (6584, group1    18425641
# group2    22736876
# weight          10
# Name: 6584, dtype: int64)
# (6585, group1    1697586
# group2    1187715
# weight          2
# Name: 6585, dtype: int64)
# (6586, group1    1697586
# group2    1642477
# weight          1
# Name: 6586, dtype: int64)
# (6587, group1    1451826
# group2    1187715
# weight          1
# Name: 6587, dtype: int64)
# (6588, group1     1451826
# group2    18180033
# weight           1
# Name: 6588, dtype: int64)
# (6589, group1     1451826
# group2    19064659
# weight           1
# Name: 6589, dtype: int64)
# (6590, group1    1451826
# group2    1371991
# weight          1
# Name: 6590, dtype: int64)
# (6591, group1     1451826
# group2    20129636
# weight           1
# Name: 6591, dtype: int64)
# (6592, group1     8908602
# group2    21245809
# weight           1
# Name: 6592, dtype: int64)
# (6593, group1    8908602
# group2    1187715
# weight          1
# Name: 6593, dtype: int64)
# (6594, group1     8908602
# group2    19822479
# weight           1
# Name: 6594, dtype: int64)
# (6595, group1     8908602
# group2    22736876
# weight           1
# Name: 6595, dtype: int64)
# (6596, group1     7700282
# group2    19822479
# weight           1
# Name: 6596, dtype: int64)
# (6597, group1    7700282
# group2     204767
# weight          1
# Name: 6597, dtype: int64)
# (6598, group1     7700282
# group2    22736876
# weight           2
# Name: 6598, dtype: int64)
# (6599, group1    18767675
# group2    17872862
# weight           1
# Name: 6599, dtype: int64)
# (6600, group1    18767675
# group2    17467312
# weight           1
# Name: 6600, dtype: int64)
# (6601, group1    14380872
# group2    19822479
# weight           1
# Name: 6601, dtype: int64)
# (6602, group1    19496778
# group2    18589616
# weight           1
# Name: 6602, dtype: int64)
# (6603, group1    19496778
# group2      526316
# weight           1
# Name: 6603, dtype: int64)
# (6604, group1    23353167
# group2    20135762
# weight           1
# Name: 6604, dtype: int64)
# (6605, group1    23353167
# group2     1187715
# weight           1
# Name: 6605, dtype: int64)
# (6606, group1    23353167
# group2    23594916
# weight           1
# Name: 6606, dtype: int64)
# (6607, group1    23353167
# group2    17467312
# weight           2
# Name: 6607, dtype: int64)
# (6608, group1    23353167
# group2    18589616
# weight           1
# Name: 6608, dtype: int64)
# (6609, group1    23353167
# group2    18616278
# weight           2
# Name: 6609, dtype: int64)
# (6610, group1    23353167
# group2    17872862
# weight           2
# Name: 6610, dtype: int64)
# (6611, group1    23353167
# group2    19654655
# weight           1
# Name: 6611, dtype: int64)
# (6612, group1     7151442
# group2    18779992
# weight           3
# Name: 6612, dtype: int64)
# (6613, group1     7151442
# group2    17467312
# weight           5
# Name: 6613, dtype: int64)
# (6614, group1     7151442
# group2    18589616
# weight           3
# Name: 6614, dtype: int64)
# (6615, group1     7151442
# group2    18616278
# weight           4
# Name: 6615, dtype: int64)
# (6616, group1     7151442
# group2    17872862
# weight           2
# Name: 6616, dtype: int64)
# (6617, group1    7151442
# group2     526316
# weight          1
# Name: 6617, dtype: int64)
# (6618, group1     7151442
# group2    19654655
# weight           3
# Name: 6618, dtype: int64)
# (6619, group1    19064659
# group2     1187715
# weight           1
# Name: 6619, dtype: int64)
# (6620, group1    20135762
# group2    17872862
# weight           3
# Name: 6620, dtype: int64)
# (6621, group1     1371991
# group2    20129636
# weight           1
# Name: 6621, dtype: int64)
# (6622, group1    1371991
# group2    1763190
# weight          1
# Name: 6622, dtype: int64)
# (6623, group1    1371991
# group2    1187715
# weight         27
# Name: 6623, dtype: int64)
# (6624, group1     1371991
# group2    24803205
# weight           4
# Name: 6624, dtype: int64)
# (6625, group1     1371991
# group2    18923420
# weight           1
# Name: 6625, dtype: int64)
# (6626, group1     1371991
# group2    18589616
# weight           1
# Name: 6626, dtype: int64)
# (6627, group1    1371991
# group2    1349592
# weight          5
# Name: 6627, dtype: int64)
# (6628, group1    1371991
# group2    1576921
# weight          1
# Name: 6628, dtype: int64)
# (6629, group1    1371991
# group2     526316
# weight          1
# Name: 6629, dtype: int64)
# (6630, group1    1371991
# group2    1642477
# weight          9
# Name: 6630, dtype: int64)
# (6631, group1    18779992
# group2    18589616
# weight           5
# Name: 6631, dtype: int64)
# (6632, group1    18779992
# group2    17467312
# weight           4
# Name: 6632, dtype: int64)
# (6633, group1    18779992
# group2    18616278
# weight           2
# Name: 6633, dtype: int64)
# (6634, group1    18779992
# group2    17872862
# weight           3
# Name: 6634, dtype: int64)
# (6635, group1    20129636
# group2     1187715
# weight           2
# Name: 6635, dtype: int64)
# (6636, group1    20129636
# group2    22730657
# weight           1
# Name: 6636, dtype: int64)
# (6637, group1    21245809
# group2    19822479
# weight           1
# Name: 6637, dtype: int64)
# (6638, group1    1763190
# group2    1187715
# weight          1
# Name: 6638, dtype: int64)
# (6639, group1     1763190
# group2    18923420
# weight           5
# Name: 6639, dtype: int64)
# (6640, group1     1763190
# group2    18589616
# weight           1
# Name: 6640, dtype: int64)
# (6641, group1    1763190
# group2     526316
# weight          3
# Name: 6641, dtype: int64)
# (6642, group1    25718653
# group2    18476981
# weight           1
# Name: 6642, dtype: int64)
# (6643, group1     1187715
# group2    24803205
# weight           5
# Name: 6643, dtype: int64)
# (6644, group1     1187715
# group2    23674770
# weight           1
# Name: 6644, dtype: int64)
# (6645, group1     1187715
# group2    18923420
# weight           1
# Name: 6645, dtype: int64)
# (6646, group1     1187715
# group2    22730657
# weight           1
# Name: 6646, dtype: int64)
# (6647, group1     1187715
# group2    18589616
# weight           3
# Name: 6647, dtype: int64)
# (6648, group1     1187715
# group2    17467312
# weight           1
# Name: 6648, dtype: int64)
# (6649, group1    1187715
# group2    1349592
# weight          5
# Name: 6649, dtype: int64)
# (6650, group1    1187715
# group2    1576921
# weight          4
# Name: 6650, dtype: int64)
# (6651, group1     1187715
# group2    18882523
# weight           1
# Name: 6651, dtype: int64)
# (6652, group1     1187715
# group2    17872862
# weight           1
# Name: 6652, dtype: int64)
# (6653, group1     1187715
# group2    18573279
# weight           1
# Name: 6653, dtype: int64)
# (6654, group1    1187715
# group2    6121452
# weight          1
# Name: 6654, dtype: int64)
# (6655, group1    1187715
# group2    1642477
# weight         11
# Name: 6655, dtype: int64)
# (6656, group1    1187715
# group2     526316
# weight          1
# Name: 6656, dtype: int64)
# (6657, group1     1187715
# group2    19654655
# weight           1
# Name: 6657, dtype: int64)
# (6658, group1    24803205
# group2    18589616
# weight           1
# Name: 6658, dtype: int64)
# (6659, group1    24803205
# group2     1349592
# weight           1
# Name: 6659, dtype: int64)
# (6660, group1    24803205
# group2     1642477
# weight           1
# Name: 6660, dtype: int64)
# (6661, group1    19822479
# group2    18589616
# weight           1
# Name: 6661, dtype: int64)
# (6662, group1    19822479
# group2    18616278
# weight           1
# Name: 6662, dtype: int64)
# (6663, group1    23674770
# group2    25587693
# weight           2
# Name: 6663, dtype: int64)
# (6664, group1    18923420
# group2    18589616
# weight           1
# Name: 6664, dtype: int64)
# (6665, group1    23594916
# group2    18589616
# weight           1
# Name: 6665, dtype: int64)
# (6666, group1    23594916
# group2    17467312
# weight           1
# Name: 6666, dtype: int64)
# (6667, group1    24850344
# group2    23515107
# weight           1
# Name: 6667, dtype: int64)
# (6668, group1    24850344
# group2      526316
# weight           1
# Name: 6668, dtype: int64)
# (6669, group1    17467312
# group2    18589616
# weight           3
# Name: 6669, dtype: int64)
# (6670, group1    17467312
# group2    18616278
# weight           2
# Name: 6670, dtype: int64)
# (6671, group1    17467312
# group2    17872862
# weight           1
# Name: 6671, dtype: int64)
# (6672, group1    17467312
# group2    19654655
# weight           5
# Name: 6672, dtype: int64)
# (6673, group1    18589616
# group2    18616278
# weight           8
# Name: 6673, dtype: int64)
# (6674, group1    18589616
# group2     1349592
# weight           1
# Name: 6674, dtype: int64)
# (6675, group1    18589616
# group2    17872862
# weight           3
# Name: 6675, dtype: int64)
# (6676, group1    18589616
# group2       47094
# weight           1
# Name: 6676, dtype: int64)
# (6677, group1    18476981
# group2      526316
# weight           1
# Name: 6677, dtype: int64)
# (6678, group1    18616278
# group2    18882523
# weight           1
# Name: 6678, dtype: int64)
# (6679, group1    18616278
# group2    17872862
# weight           1
# Name: 6679, dtype: int64)
# (6680, group1    18616278
# group2    22736876
# weight           1
# Name: 6680, dtype: int64)
# (6681, group1    18616278
# group2    19654655
# weight           2
# Name: 6681, dtype: int64)
# (6682, group1     1349592
# group2    18573279
# weight           1
# Name: 6682, dtype: int64)
# (6683, group1    1349592
# group2     526316
# weight          1
# Name: 6683, dtype: int64)
# (6684, group1    1349592
# group2    1642477
# weight          1
# Name: 6684, dtype: int64)
# (6685, group1    1349592
# group2      47094
# weight          2
# Name: 6685, dtype: int64)
# (6686, group1    1576921
# group2     526316
# weight          1
# Name: 6686, dtype: int64)
# (6687, group1    1576921
# group2    1642477
# weight          2
# Name: 6687, dtype: int64)
# (6688, group1    18882523
# group2    18573279
# weight           1
# Name: 6688, dtype: int64)
# (6689, group1    18882523
# group2    19654655
# weight           1
# Name: 6689, dtype: int64)
# (6690, group1    18573279
# group2    19654655
# weight           2
# Name: 6690, dtype: int64)
# (6691, group1    23515107
# group2      526316
# weight           1
# Name: 6691, dtype: int64)

# %% [markdown]
# ## Visualize the Network

# %%
#Your code here

# %% [markdown]
# ## Refine the Visual
#
# As you should see, the initial visualization is a globular mess! Refine the visualization to better picture the center core of the  network.

# %%
#Your code here

# %% [markdown]
# ## Try Clustering the Network
#
# Now, that the dataset is a little more manageable, try clustering the remaining group nodes.

# %%
#Your code here

# %% [markdown]
# ## Determine An Optimal Clustering Schema
#
# Finally, determine a final clustering organization.

# %%
#Your code here

# %% [markdown]
# ## Visualize the Clusters
#
# Analyze the output of your clustering schema. Do any clusters of groups stand out to you?

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# In this lab, you got another chance to practice your network clustering skills, investigating a meetup dataset of events and groups surrounding the Nashville area. If you're up for the challenge, feel free to continue investigating the dataset and trying to cluster users or events!
